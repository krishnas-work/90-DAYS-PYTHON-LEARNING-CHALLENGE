# %%
# Q1: Write a program to print: Hello, World
# sol:
print("Hello, World")
# Out:
# Hello, World

# %%
# Q2: Write a program to store your name in a variable and print it
# sol:
a="krishna sharma"
print(a)
# Out:
# krishna sharma

# %%
# Q3: Take one number , store it in variable and print it.
# sol:
a=14
print(a)
# Out:
# 14

# %%
# Q4: Take two numbers and print their sum.
# sol: 
m=12
n=34
print(m+n)
# Out:
# 46

# %%
# Q5: Take two numbers and print their product
# sol:
x=11
y=67
print(x*y)
# Out:
# 737
