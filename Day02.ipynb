# %%
# Q1: Take a number as input and check whether it is greater than 10 or not.
# sol:
x=int(input("enter a number:"))
if x>10:
    print("x is greater")
# Out:
# enter a number: 19
# x is greater

# %%
# Q2: Take your marks as input and print:
#      "Pass" if marks ≥ 40
#      "Fail" otherwise

# sol:
x=int(input("Enter your marks:"))
if x>40:
    print("pass")
else:
    print("Fail")
# Out:
# Enter your marks: 35
# Fail

# %%
# Q3 Take a number and check whether it is positive, negative, or zero.
# sol: 
x=int(input("enter a number"))
if x>0:
    print("The number is positive")
if x<0:
    print("The number is negative")
else:
    print("The number is zero")
# Out:
# enter a number -32
# The number is negative

# %%
# Q4: Take two numbers and print which one is larger, or print "Both are equal" if they are same.
# sol:
x=int(input("enter first number:"))
y=int(input("enter second number:"))
if x>y:
    print("x is greater")
if x<y:
    print("y is greater")
if x==y:
    print("both are equal")
# Out:
# enter first number: 12
# enter second number: 56
# y is greater

# %%
# Q5: Take a character as input and check whether it is a vowel or consonant.
# sol:
x=input("Enter a charcahcter:")
l="a,e,i,o,u"
if x==l:
    print("Char. is a vowel")
else:
    print("Char. is a consonant")
# Out:
# Enter a charcahcter: Y
# Char. is a consonant
